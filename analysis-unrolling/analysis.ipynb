# %%
import pandas as pd
import seaborn as sns

# %%
df_fscale = pd.read_csv("fscale.csv")
df_inc = pd.read_csv("inc.csv")
df_movl = pd.read_csv("movl.csv")
df_nop = pd.read_csv("nop.csv")
df_rdrand = pd.read_csv("rdrand.csv")
df_xor = pd.read_csv("xor.csv")

# %%
df_fscale['Count'] = df_fscale.groupby('Measurements')['Measurements'].transform('size')
df_inc['Count'] = df_inc.groupby('Measurements')['Measurements'].transform('size')
df_movl['Count'] = df_movl.groupby('Measurements')['Measurements'].transform('size')
df_nop['Count'] = df_nop.groupby('Measurements')['Measurements'].transform('size')
df_rdrand['Count'] = df_rdrand.groupby('Measurements')['Measurements'].transform('size')
df_xor['Count'] = df_xor.groupby('Measurements')['Measurements'].transform('size')

# %%
df_fscale = df_fscale.drop_duplicates()
df_inc = df_inc.drop_duplicates()
df_movl = df_movl.drop_duplicates()
df_nop = df_nop.drop_duplicates()
df_rdrand = df_rdrand.drop_duplicates()
df_xor = df_xor.drop_duplicates()

# %% [markdown]
# ## Analysis of fscale ##

# %%
sns.lineplot(x="Measurements",y="Count",data=df_fscale)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df_fscale = df_fscale[(df_fscale[['Measurements']] != 0).all(axis=1)]
df_fscale = df_fscale[(df_fscale[['Measurements']] < 580000).all(axis=1)]
df_fscale = df_fscale[(df_fscale[['Measurements']] > 540000).all(axis=1)]

# %%
sns.lineplot(x="Measurements",y="Count",data=df_fscale)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Analysis of inc ##

# %%
sns.lineplot(x="Measurements",y="Count",data=df_inc)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df_inc = df_inc[(df_inc[['Measurements']] != 0).all(axis=1)]
df_inc = df_inc[(df_inc[['Measurements']] < 7000).all(axis=1)]
df_inc = df_inc[(df_inc[['Measurements']] > 5000).all(axis=1)]

# %%
sns.lineplot(x="Measurements",y="Count",data=df_inc)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Analysis of movl ##

# %%
sns.lineplot(x="Measurements",y="Count",data=df_movl)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df_movl = df_movl[(df_movl[['Measurements']] != 0).all(axis=1)]
df_movl = df_movl[(df_movl[['Measurements']] < 8000).all(axis=1)]
df_movl = df_movl[(df_movl[['Measurements']] > 6000).all(axis=1)]

# %%
sns.lineplot(x="Measurements",y="Count",data=df_movl)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Analysis of nop ##

# %%
sns.lineplot(x="Measurements",y="Count",data=df_nop)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df_nop = df_nop[(df_nop[['Measurements']] != 0).all(axis=1)]
df_nop = df_nop[(df_nop[['Measurements']] < 8000).all(axis=1)]
df_nop = df_nop[(df_nop[['Measurements']] > 6000).all(axis=1)]

# %%
sns.lineplot(x="Measurements",y="Count",data=df_nop)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Analysis of rdrand ##

# %%
# Was last measurement I took and I think the screen went in to sleep mode
sns.lineplot(x="Measurements",y="Count",data=df_rdrand)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Analysis of xor ##

# %%
sns.lineplot(x="Measurements",y="Count",data=df_xor)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df_xor = df_xor[(df_xor[['Measurements']] != 0).all(axis=1)]
df_xor = df_xor[(df_xor[['Measurements']] < 7000).all(axis=1)]
df_xor = df_xor[(df_xor[['Measurements']] > 6000).all(axis=1)]

# %%
sns.lineplot(x="Measurements",y="Count",data=df_xor)
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %% [markdown]
# ## Trying to compare different operations ##

# %%
df_fscale["instruction"] = "fscale"
df_inc["instruction"] = "inc"
df_movl["instruction"] = "movl"
df_nop["instruction"] = "nop"
df_rdrand["instruction"] = "rdrand"
df_xor["instruction"] = "xor"

# %%
df = df_fscale.append(df_inc)
df = df.append(df_movl)
df = df.append(df_nop)
df = df.append(df_rdrand)
df = df.append(df_xor)

# %%
sns.lineplot(x="Measurements",y="Count",data=df,hue="instruction")
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>

# %%
df = df[(df.T != 0).any()]

# %%
sns.lineplot(x="Measurements",y="Count",data=df,hue="instruction")
# Out:
# <AxesSubplot:xlabel='Measurements', ylabel='Count'>
